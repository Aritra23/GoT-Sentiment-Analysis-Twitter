# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from textblob import TextBlob
from tweepy import Stream
from bs4 import BeautifulSoup
import requests
import pprint
import json
import pandas as pd
import pymongo
from sqlalchemy import func

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
# Define the 'classDB' database in Mongo
db = client.projDB
tweet = db.tweet_hashtag.find()

# %%
df = pd.DataFrame(columns=["character", "id", "text", "language","created", "place", "source", "sentiment"])
df1 = df

# %%
count = 0
for each_tweet in tweet:
#     print(each_tweet)
#     print("")
#     print (each_tweet["id"])
#     print(each_tweet["text"])
    analysis = TextBlob(each_tweet["text"])
#     print(analysis.sentiment)
    senti = ""
    if analysis.sentiment[0]>0:
#        print("pos")
       senti = "Pos"
    elif analysis.sentiment[0]<0:
#        print("neg")
       senti = "Neg"
    else:
#        print("neu")
       senti = "Neu"
    
#     name = each_tweet["entities"]
#     print(each_tweet["entities"])
#     print("")
#     print(each_tweet["entities"]["hashtags"][0]["text"])
    if each_tweet["entities"]["hashtags"] is None:
        char_name = ""
    else:
        if len(each_tweet["entities"]["hashtags"]) > 0:
            char_name = each_tweet["entities"]["hashtags"][0]["text"]
    
    print(char_name)
    try: 
        df1 = pd.DataFrame({"character": char_name, "id": each_tweet["id"], "text": each_tweet["text"], "language": each_tweet["language"], "created": each_tweet["created"], "place": each_tweet["place"], "source": each_tweet["source"], "sentiment": [senti]})
        df = df.append(df1, ignore_index=True)
    except:
        print(each_tweet)
        print(f'{char_name}, {each_tweet["id"]}, {each_tweet["text"]}, {each_tweet["language"]}, {each_tweet["created"]}, {each_tweet["place"]}, {each_tweet["source"]}, {[senti]}')
    count += 1
    if count > 100:
        break
# Out:
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GOT
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# BarryHBO
# GameOfThrones
# GameofThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameofThrones
# GameofThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GoTS8
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameofThrones
# gots8
# gots8
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameofThrones
# GameOfThrones
# GOT
# GOT
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# got
# thread
# GameofThrones
# GOT
# GOT
# GOT
# GameofThrones
# GoT
# GameofThrones
# GameofThrones
# GameofThrones
# GameofThrones
# GameOfThrones
# GameofThrones
# GameofThrones
# GameOfThrones
# GameOfThrones
# Shadowhunters
# GoTS8
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameofThrones
# GameofThrones
# GameofThrones
# GoTS8
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameofThrones
# GameofThrones
# GameofThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameofThrones
# GameofThrones
# GameofThrones
# {'_id': ObjectId('5cd70a7345375848c45d86e4'), 'id': 1127268702867656704, 'text': '.@GameOfThrones the treatment of Ghost is not a just a mistreatment of a major character but a fundamental lack of… https://t.co/uXZ85H63uz', 'language': 'en', 'created': 'Sat May 11 17:46:17 +0000 2019', 'entities': {'hashtags': [], 'urls': [{'url': 'https://t.co/uXZ85H63uz', 'expanded_url': 'https://twitter.com/i/web/status/1127268702867656704', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}], 'user_mentions': [{'screen_name': 'GameOfThrones', 'name': 'Game of Thrones', 'id': 180463340, 'id_str': '180463340', 'indices': [1, 15]}], 'symbols': []}, 'place': {'id': '446dd74cab94bc2c', 'url': 'https://api.twitter.com/1.1/geo/id/446dd74cab94bc2c.json', 'place_type': 'city', 'name': 'North Bay', 'full_name': 'North Bay, Ontario', 'country_code': 'CA', 'country': 'Canada', 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-79.505086, 46.222736], [-79.505086, 46.44822], [-79.255964, 46.44822], [-79.255964, 46.222736]]]}, 'attributes': {}}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>'}
# GameofThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones
# GameOfThrones

# %%
df1["text"]

# %%
df1.head()
